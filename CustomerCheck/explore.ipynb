# %%
import pandas as pd

# %%
df_v = pd.read_csv('train_values.csv', delimiter=',', index_col='row_id')
df_l = pd.read_csv('train_labels.csv', delimiter=',', index_col='row_id')

# %%
df_l
# Out:
#         accepted
# row_id
# 0              1
# 1              0
# 2              1
# 3              1
# 4              1
# ...          ...
# 499995         0
# 499996         0
# 499997         0
# 499998         0
# 499999         0
#
# [500000 rows x 1 columns]

# %%
df = pd.concat([df_v, df_l], axis=1 )

# %%
df.sample(10)
# Out:
#         loan_type  property_type  loan_purpose  occupancy  loan_amount  \
# row_id
# 19789           1              1             3          1        595.0
# 55865           1              1             1          1        236.0
# 121874          1              1             1          1         71.0
# 428074          1              1             1          1        125.0
# 476759          1              1             1          1        614.0
# 113426          1              1             3          1        314.0
# 176135          2              1             3          1        217.0
# 227555          1              1             1          2        171.0
# 488232          3              1             3          1        324.0
# 41358           1              1             1          1        193.0
#
#         preapproval  msa_md  state_code  county_code  applicant_ethnicity  \
# row_id
# 19789             3     322          37          100                    2
# ...
